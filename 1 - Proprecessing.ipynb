# %% [markdown]
# <center> <h1>XXX Datathon - Team n°1</h1> </center>

# %% [markdown]
# ## In this notebook:
#
# This Jupyter Notebook will be used to preprocess the data. We start with the given dataset ```DATASET_Train2.xlsx``` and we successively apply different transformations.
#
# 1) Data preprocessing
#
# 2) Data transformation, as specified in transform.py
#
# 3) Merging of external data: hazard, UW ratio, market index
#
# The output dataset will be store in the ```processed_data.csv``` csv file.
#
#
# ### Assumptions
#
# 1) Some of the data was already preprocessed using external tools. In particular, we have preprocessed the column ```DEDUCTIBLES``` which had a messy structure. As a result, the following features were added to the original XXX dataset giving this new ```DATASET_Train2``` which is the one imported in this Notebook.
#
# | Feature name          | Number of values | Type    |
# |-----------------------|------------------|---------|
# | PD_price(M)           | 5146 non-null    | float64 |
# | BI_price(M)           | 5146 non-null    | float64 |
# | BI_time(Days)         | 5146 non-null    | float64 |
# | Both_price(M)         | 5146 non-null    | float64 |
# | PD_percent_loss (%)   | 5146 non-null    | float64 |
# | BI_percent_loss (%)   | 5146 non-null    | float64 |
# | Both_percent_loss (%) | 5146 non-null    | float64 |
# | PD_percent_tiv (%)    | 5146 non-null    | float64 |
#
# #### Preprocessing of the column ```DEDUCTIBLES```
#
# - Principle : The column may indicate a price, a number of days, or a percentage for PD, BI or both. We create a column for every possible case (said columns are listed above). For each line, the concerned columns are filled with processed data from the column deductibles, and the others are filled with 0s.
# - Process :
#     1. we convert the column ```DEDUCTIBLES``` to csv format, and put it in a csv file
#     2. we use the following regular expressions (vim format) to convert the 1-column format to our 8-column format.
#         ```vimscript
# 1,$s/^PD: *\(.*\)M *, *BI: *\(.*\)Day(s)$/\1; 0; \2; 0; 0; 0; 0; 0
# 1,$s/^PD: *\(.*\)M *, *BI: *\(.*\)M *$/\1; \2; 0; 0; 0; 0; 0; 0
# 1,$s/^PD: *\(.*\)% *of *loss *, *BI: *\(.*\)Day(s)$/0; 0; \2; 0; \1; 0; 0; 0
# 1,$s/^PD: *\(.*\)% *of *tiv *, *BI: *\(.*\)Day(s)$/0; 0; \2; 0; 0; 0; 0; \1
# 1,$s/^PD: *\(.*\)% *of *loss *, *BI: *\(.*\)M$/0; \2; 0; 0; \1; 0; 0; 0
# 1,$s/^PD: *\(.*\)M, *BI: *\(.*\)% *of *loss *$/\1; 0; 0; 0; 0; \2; 0; 0
# 1,$s/^PD,BI: *\(.*\)M$/0; 0; 0; \1; 0; 0; 0; 0/
# 1,$s/^ *BI: *\(.*\)Day(s)$/0; 0; \1; 0; 0; 0; 0; 0
# 1,$s/^PD: *\(.*\)M *$/\1; 0; 0; 0; 0; 0; 0; 0
# 1,$s/^PD: *\(.*\)% *of *loss *$/0; 0; 0; 0; \1; 0; 0; 0
# 1,$s/^PD: *\(.*\)% *of *tiv *$/0; 0; 0; 0; 0; 0; 0; \1
# %s/,/./g
#
#         ```
#
#
# 2) UW ratio data was already preprocessed in the ```UW_Ratio_Preprocessing``` file and will be directly imported in this Notebook.

# %% [markdown]
# # <font color='darkorange'>Imports </font>

# %%
import pandas as pd
import data_transform
import numpy as np
from tqdm import tqdm
from pandas import DataFrame

# Visualization options
pd.set_option('display.max_columns', 5000)
pd.set_option('display.max_rows', 5000)

# %% [markdown]
# # <font color='darkorange'>Data Loading </font>
# #### Please choose which dataset you want to load

# %%
preprocess_train = False
preprocess_test = not preprocess_train

# %%
#Original data with the preprocessing of column 'Deductible'
if preprocess_train:
    df = pd.read_excel('data/DATASET_Train2.xlsx') 
else:
    df = pd.read_csv("data/DATASET_TEST_Processed.csv", 
                          parse_dates=["INCEPTION", "EXPIRY", "PRICING_DATE"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3259 entries, 0 to 3258
# Data columns (total 63 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SUBMISSION_ID          3259 non-null   int64
#  1   DIVISION_ID            3259 non-null   int64
#  2   FACUL_NUM              3259 non-null   object
#  3   TAG                    3259 non-null   object
#  4   DIVISION_NUM           3259 non-null   int64
#  5   SEGMENT_LOB            3259 non-null   object
#  6   UF_STATUS              3259 non-null   object
#  7   CT_STATUS              3259 non-null   object
#  8   UWYEAR                 3259 non-null   object
#  9   INCEPTION_MONTH        3259 non-null   object
#  10  INCEPTION              3259 non-null   datetime64[ns]
#  11  EXPIRY                 3259 non-null   datetime64[ns]
#  12  CT_PERIOD              3259 non-null   int64
#  13  MARKET                 3258 non-null   object
#  14  SUBSECTOR              3249 non-null   object
#  15  MAINOCCUPANCY          3259 non-null   object
#  16  SECTOR                 3259 non-null   object
#  17  BUSINESSUNIT           3259 non-null   object
#  18  UWCENTER               3259 non-null   object
#  19  SCOPE_PERILS           3259 non-null   object
#  20  SUBSIDIARY             3259 non-null   object
#  21  COVERAGE               3259 non-null   object
#  22  PARTTYPE               3259 non-null   object
#  23  MAIN_COUNTRY           3227 non-null   object
#  24  GUARANTEE              3259 non-null   object
#  25  MAIN_PRICING_CATEG     3259 non-null   object
#  26  MAIN_PRICING_SUBCATEG  3258 non-null   object
#  27  BI_TYPE                3259 non-null   object
#  28  BI_PERIOD              2619 non-null   float64
#  29  TC_PROFIT_COMMISSION   3259 non-null   float64
#  30  DEDUCTIBLES            3221 non-null   object
#  31  INSUREDVALUEPD         3259 non-null   float64
#  32  INSUREDVALUEBI         2617 non-null   float64
#  33  TOTALINSUREDVALUE      3259 non-null   float64
#  34  NBLOCS                 3259 non-null   int64
#  35  OIL                    3257 non-null   float64
#  36  LIMIT                  3259 non-null   float64
#  37  ATTACHMENT             3259 non-null   float64
#  38  XXX_SHARE             3259 non-null   float64
#  39  MODELED_CAT_EXPLOSS    3259 non-null   float64
#  40  DISCOUNTS              3259 non-null   float64
#  41  DEDUCTION              3259 non-null   float64
#  42  EXT_EXPENSE            3259 non-null   float64
#  43  WORDING                3257 non-null   object
#  44  QUALITY_RISK_MGT       3257 non-null   object
#  45  ASSET_QUALITY          3257 non-null   object
#  46  BI_MITIGATION          2615 non-null   object
#  47  MB_QUALITY             1102 non-null   object
#  48  REPORTCCY              3259 non-null   object
#  49  ORIGCCY                3259 non-null   object
#  50  TXCHANGE               3259 non-null   float64
#  51  PRICING_DATE           3259 non-null   datetime64[ns]
#  52  FXRATEUSD              3259 non-null   object
#  53  TOP_MPL                3256 non-null   float64
#  54  TOP_FMLS               1104 non-null   float64
#  55  PD_price(M)            3221 non-null   float64
#  56  BI_price(M)            3221 non-null   float64
#  57  BI_time(Days)          3221 non-null   float64
#  58  Both_price(M)          3221 non-null   float64
#  59  PD_percent_loss (%)    3221 non-null   float64
#  60  BI_percent_loss (%)    3221 non-null   float64
#  61  Both_percent_loss (%)  3221 non-null   float64
#  62  PD_percent_tiv (%)     3221 non-null   float64
# dtypes: datetime64[ns](3), float64(24), int64(5), object(31)
# memory usage: 1.6+ MB

# %% [markdown]
# # <font color='darkorange'> Preprocessing Data </font>

# %% [markdown]
# The data transform function is in **data_transform.py** file.（More analysis and explanations for performing certain steps can be found in the **Exploration Analysis** notebook）
#
# To sum up, this function includes:
#
# 1) Dealing with missing values
#
# 2) Changing Cover_BI to a boolean variable that significates if BI is included in the contract
#
# 3) Grouping several sectors together
#
# 4) Grouping regional markets together(could be found in **constants.py**)
#
# 5) Removing useless variables (Variables with 99% the same value)
#
# 6) Substract *UWYEAR* and *Inception month*
#
# 7) Drop certain varaibles that we considered useless for the premium (could be found in **constants.py**)

# %%
df.drop(columns=['DEDUCTIBLES'], inplace=True)
df['DIVISION_NUM'] = df['DIVISION_NUM'].astype('str')

# %%
df_t = data_transform.transform_data(df) ;
if preprocess_test:
    df_t = df_t.drop(columns = ['BI_price(M)','PD_percent_tiv (%)'])
df_t.head()
# Out:
# (3259, 62)
# (3259, 63)
# (3259, 63)
# (3259, 64)
# ## Dropped useless features:  ['TC_PROFIT_COMMISSION', 'REPORTCCY', 'BI_percent_loss (%)', 'Both_percent_loss (%)']
# (3259, 60)
# (3259, 61)
# (3259, 62)
# (3259, 48)
#    SUBMISSION_ID  FACUL_NUM DIVISION_NUM      SEGMENT_LOB  UWYEAR  CT_PERIOD  \
# 0              1  FA0020462            1  Ppty Non Energy    2020         12
# 1              2  11F008861            1  Ppty Non Energy    2019         12
# 2              3  FA0003626            1  Ppty Non Energy    2017         12
# 3              4  11F007069            2  Ppty Non Energy    2018         12
# 4              5  11F008861            1  Ppty Non Energy    2020         12
#
#            MAINOCCUPANCY     SECTOR BUSINESSUNIT UWCENTER SCOPE_PERILS  \
# 0  Precious Metals Mines  BS Energy    BS Energy      LAC    All Risks
# 1  Precious Metals Mines  BS Energy    BS Energy      LAC    All Risks
# 2  Precious Metals Mines  BS Energy    BS Energy      LAC    All Risks
# 3  Precious Metals Mines  BS Energy    BS Energy      LAC    All Risks
# 4  Precious Metals Mines  BS Energy    BS Energy      LAC    All Risks
#
#     SUBSIDIARY        PARTTYPE GUARANTEE  MAIN_PRICING_CATEG         BI_TYPE  \
# 0  XXX CANADA     Quota-Share        EU  Mining - Hard Rock  Loss of profit
# 1  XXX CANADA     Quota-Share        EU  Mining - Hard Rock  Loss of profit
# 2   XXX RE US  Excess of Loss        EU  Mining - Hard Rock  Loss of profit
# 3  XXX CANADA     Quota-Share        EU  Mining - Hard Rock  Loss of profit
# 4  XXX CANADA     Quota-Share        EU  Mining - Hard Rock  Loss of profit
#
#    BI_PERIOD  INSUREDVALUEPD  INSUREDVALUEBI  TOTALINSUREDVALUE  NBLOCS  OIL  \
# 0       12.0    6.386765e+08    3.094686e+08       9.481450e+08       3  0.0
# 1       12.0    6.120514e+08    1.912141e+08       8.032655e+08       3  0.0
# 2       24.0    1.585276e+09    5.624312e+08       2.147707e+09       1  0.0
# 3       24.0    8.259934e+08    9.739950e+08       1.799988e+09       2  0.0
# 4       12.0    6.387283e+08    3.094292e+08       9.481575e+08       3  0.0
#
#          LIMIT  ATTACHMENT  XXX_SHARE  MODELED_CAT_EXPLOSS  DISCOUNTS  \
# 0  180635834.0         0.0       0.025                  0.0        0.0
# 1  175963400.0         0.0       0.075                  0.0        0.0
# 2  278732700.0         0.0       0.075                  0.0        0.0
# 3  589622642.0         0.0       0.120                  0.0        0.0
# 4  180635834.0         0.0       0.075                  0.0        0.0
#
#    DEDUCTION  EXT_EXPENSE   WORDING QUALITY_RISK_MGT ASSET_QUALITY  \
# 0   0.072997     0.072997  Standard          Average       Average
# 1   0.093420     0.093420  Standard          Average       Average
# 2   0.095564     0.095564  Standard          Average       Average
# 3   0.635696     0.635696  Standard          Average       Average
# 4   0.080394     0.080394  Standard          Average       Average
#
#   BI_MITIGATION MB_QUALITY  TXCHANGE FXRATEUSD       TOP_MPL  TOP_FMLS  \
# 0       Average    Average  0.903179         1  2.500444e+08       0.0
# 1       Average    Average  0.879817         1  2.097005e+08       0.0
# 2       Average    Average  0.929109         1  8.826536e+08       0.0
# 3       Average    Average  0.842318         1  9.285377e+08       0.0
# 4       Average    Average  0.903179         1  2.500452e+08       0.0
#
#    PD_price(M)  BI_time(Days)  Both_price(M)  PD_percent_loss (%)  COVER_BI  \
# 0          0.5           30.0            0.0                  0.0      True
# 1          0.4           30.0            0.0                  0.0      True
# 2          4.6           30.0            0.0                  0.0      True
# 3          2.1           30.0            0.0                  0.0      True
# 4          0.5           30.0            0.0                  0.0      True
#
#   GEO_MARKET_SEGMENT UWYEAR_label  INCEPTION_month
# 0      Latin America            1                6
# 1      Latin America            1                6
# 2      Latin America            1               10
# 3      Latin America            1                5
# 4      Latin America            1                6

# %% [markdown]
# We now have our preliminary dataset. It has 46 different features both categorical and numerical. We will now concatenate external data to this dataset to make it more relevant for our ```PREMIUM``` prediction problem.

# %% [markdown]
# # <font color='darkorange'> Merge External Data </font>

# %% [markdown]
# ### HAZARD data
#
# In this section, we will utilise the information in ```exposure_data_v3.csv``` to obtain a new predictor **WEIGHTED HAZARD**, which depicts the seismic hazard as Peak Ground Acceleration(PGA), averaged across all the locations for each contract (grouped using **UWYEAR**, **FACUL_NUM** and **DIVISION_NUM**) and weighted by **TOTALINSUREDVALUE**. Here we fill the missing value of Insured Value BI and PD with 0, then we add them together to calculate the **TIV**: total insured value.
#
# The rationale for adding this data is that there is a positve correlation between **HAZARD** and risk of incurring loss due to seismic activities. Subsequently, the risk will affect the pricing of the premium.
#
#
# To derive this predictor, we use the database "Global Seismic Hazard Map Data"(http://gmo.gfz-potsdam.de/pub/gshap_data/gshap_data_frame.html), which is indexed by longitude and latitude. We merge exposure data to this database using **LONGITUDE** and **LATITUDE** as key. We then aggregate and average the seismic hazard across all sites for each contract.

# %%
df_exp = pd.read_csv('data/exposure_data_v3.csv')
df_exp = df_exp.drop_duplicates()
#Deal with missing values in columns = ['IV_BI_VAL','IV_PD','IV_BI_VAL']
df_exp['IV_BI_VAL'] = df_exp['IV_BI_VAL'].fillna(0.)
df_exp['IV_PD'] = df_exp['IV_PD'].fillna(0.)
df_exp['TIV'] = df_exp['IV_BI_VAL'] + df_exp['IV_PD']

# %%
lat_long = df_exp[['FACUL_NUM','YEAR', 'DIVISION_NUM', 'LONGITUDE','LATITUDE','TIV']]

# %%
header_list = ['LONGITUDE', 'LATITUDE', 'HAZARD']
smc = pd.read_csv('data/GSHPUB.DAT', 
                 sep="\s+", #separator whitespace
                 header=None,
                 names = header_list)

# %% [markdown]
# The weighted average hazard is calculated here. We have used the total insured value as weight because this correspond to the gravity of possible loss.(This weighted hazard implies the max loss times the probability of loss)

# %%
hazard = pd.merge(lat_long, smc,  how='left',on=['LONGITUDE','LATITUDE'])
hazard['DIVISION_NUM'] = hazard['DIVISION_NUM'].astype('str')
hazard['weighted_hazard'] = hazard['TIV']*hazard['HAZARD']
hazard_mean = DataFrame({'weighted_hazard' : hazard.groupby(['FACUL_NUM', 'YEAR', 'DIVISION_NUM']).mean()['weighted_hazard'], 'sum_TIV':hazard.groupby(['FACUL_NUM', 'YEAR', 'DIVISION_NUM']).sum()['TIV']}).reset_index()
hazard_mean['weighted_hazard'] = hazard_mean['weighted_hazard']/hazard_mean['sum_TIV']
hazard_mean=hazard_mean.drop(columns=['sum_TIV'])

# %%
df_th = pd.merge(hazard_mean,
                df_t,
                how='right',
                left_on=['FACUL_NUM', 'YEAR', 'DIVISION_NUM'],
                right_on=['FACUL_NUM', 'UWYEAR', 'DIVISION_NUM']
               )

# %%
df_th.head()
# Out:
#    FACUL_NUM  YEAR DIVISION_NUM  weighted_hazard  SUBMISSION_ID  \
# 0  FA0020462  2020            1         0.449224              1
# 1  11F008861  2019            1         0.479085              2
# 2  FA0003626  2017            1         2.872240              3
# 3  11F007069  2018            2         0.025928              4
# 4  11F008861  2020            1         0.449208              5
#
#        SEGMENT_LOB  UWYEAR  CT_PERIOD          MAINOCCUPANCY     SECTOR  \
# 0  Ppty Non Energy    2020         12  Precious Metals Mines  BS Energy
# 1  Ppty Non Energy    2019         12  Precious Metals Mines  BS Energy
# 2  Ppty Non Energy    2017         12  Precious Metals Mines  BS Energy
# 3  Ppty Non Energy    2018         12  Precious Metals Mines  BS Energy
# 4  Ppty Non Energy    2020         12  Precious Metals Mines  BS Energy
#
#   BUSINESSUNIT UWCENTER SCOPE_PERILS   SUBSIDIARY        PARTTYPE GUARANTEE  \
# 0    BS Energy      LAC    All Risks  XXX CANADA     Quota-Share        EU
# 1    BS Energy      LAC    All Risks  XXX CANADA     Quota-Share        EU
# 2    BS Energy      LAC    All Risks   XXX RE US  Excess of Loss        EU
# 3    BS Energy      LAC    All Risks  XXX CANADA     Quota-Share        EU
# 4    BS Energy      LAC    All Risks  XXX CANADA     Quota-Share        EU
#
#    MAIN_PRICING_CATEG         BI_TYPE  BI_PERIOD  INSUREDVALUEPD  \
# 0  Mining - Hard Rock  Loss of profit       12.0    6.386765e+08
# 1  Mining - Hard Rock  Loss of profit       12.0    6.120514e+08
# 2  Mining - Hard Rock  Loss of profit       24.0    1.585276e+09
# 3  Mining - Hard Rock  Loss of profit       24.0    8.259934e+08
# 4  Mining - Hard Rock  Loss of profit       12.0    6.387283e+08
#
#    INSUREDVALUEBI  TOTALINSUREDVALUE  NBLOCS  OIL        LIMIT  ATTACHMENT  \
# 0    3.094686e+08       9.481450e+08       3  0.0  180635834.0         0.0
# 1    1.912141e+08       8.032655e+08       3  0.0  175963400.0         0.0
# 2    5.624312e+08       2.147707e+09       1  0.0  278732700.0         0.0
# 3    9.739950e+08       1.799988e+09       2  0.0  589622642.0         0.0
# 4    3.094292e+08       9.481575e+08       3  0.0  180635834.0         0.0
#
#    XXX_SHARE  MODELED_CAT_EXPLOSS  DISCOUNTS  DEDUCTION  EXT_EXPENSE  \
# 0       0.025                  0.0        0.0   0.072997     0.072997
# 1       0.075                  0.0        0.0   0.093420     0.093420
# 2       0.075                  0.0        0.0   0.095564     0.095564
# 3       0.120                  0.0        0.0   0.635696     0.635696
# 4       0.075                  0.0        0.0   0.080394     0.080394
#
#     WORDING QUALITY_RISK_MGT ASSET_QUALITY BI_MITIGATION MB_QUALITY  TXCHANGE  \
# 0  Standard          Average       Average       Average    Average  0.903179
# 1  Standard          Average       Average       Average    Average  0.879817
# 2  Standard          Average       Average       Average    Average  0.929109
# 3  Standard          Average       Average       Average    Average  0.842318
# 4  Standard          Average       Average       Average    Average  0.903179
#
#   FXRATEUSD       TOP_MPL  TOP_FMLS  PD_price(M)  BI_time(Days)  \
# 0         1  2.500444e+08       0.0          0.5           30.0
# 1         1  2.097005e+08       0.0          0.4           30.0
# 2         1  8.826536e+08       0.0          4.6           30.0
# 3         1  9.285377e+08       0.0          2.1           30.0
# 4         1  2.500452e+08       0.0          0.5           30.0
#
#    Both_price(M)  PD_percent_loss (%)  COVER_BI GEO_MARKET_SEGMENT  \
# 0            0.0                  0.0      True      Latin America
# 1            0.0                  0.0      True      Latin America
# 2            0.0                  0.0      True      Latin America
# 3            0.0                  0.0      True      Latin America
# 4            0.0                  0.0      True      Latin America
#
#   UWYEAR_label  INCEPTION_month
# 0            1                6
# 1            1                6
# 2            1               10
# 3            1                5
# 4            1                6

# %%
df_t = df_th.drop(columns=['YEAR'])

# %% [markdown]
# ### UW Ratio
#
# The preprocessing of UW Ratio is explained in the file ```A - UW Ratio Preprocessing```.
# We have constructed an uw index that could show the influence of past loss. The formula is $uw\_index = uw_{-1}+\alpha*uw_{-2}+...+\alpha^{my-1}*uw_{-my}$, where $uw_{-i}$ means the uw ratio i year before the underwriting year(UWYEAR) of the contract. We have used a decay parameter $\alpha$ to represent the decaying influence of a loss many years ago and thus the 'present value' of the uw ratio. We have tuned these two parameters with a basic XGBoost regressor and the best result is $\alpha=0.5$ and $my=7$. This corresponds also to the convention that asks to keep the accident record for 7 years in the some type of insurance(car insurance for example).

# %%
# %run 'A - UW Ratio Preprocessing.ipynb'
# Out:
# Requirement already satisfied: tqdm in /Users/liuxuwen/opt/anaconda3/lib/python3.8/site-packages (4.50.2)
#   0%|          | 0/2133 [00:00<?, ?it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18481 entries, 0 to 18480
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FACUL_NUM      18481 non-null  object
#  1   UWYEAR         18481 non-null  int64
#  2   UW_RATIO_2014  10717 non-null  float64
#  3   UW_RATIO_2015  11932 non-null  float64
#  4   UW_RATIO_2016  13281 non-null  float64
#  5   UW_RATIO_2017  14743 non-null  float64
#  6   UW_RATIO_2018  16180 non-null  float64
#  7   UW_RATIO_2019  17475 non-null  float64
#  8   UW_RATIO_2020  18375 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.3+ MB
# 100%|██████████| 2133/2133 [01:36<00:00, 22.04it/s]

# %%
df_uw = data# data is given by the A - UW Ratio Preprocessing.ipynb notebook
df_t_uw = pd.merge(df_t, df_uw, how='left', on=['FACUL_NUM', 'UWYEAR'],left_index=True).reset_index().drop(columns=['index'])
df_t_uw = df_t_uw.fillna(0)

# %%
def uw_index(df,alpha,max_year):
    """
    alpha is the decay parameter,
    max_year=1 : we only takes the last year's UW ratio into account 
    """    
    df1 = df.copy()
    df1['uw_index'] = 0.
    for index, row in df1.iterrows(): 
        y = row['UWYEAR']
        uw_index = 0
        for i in range(0,max_year):
            uw_index += row[str(y-i-1)]*pow(alpha,i)
        df1.at[index,'uw_index'] = uw_index   
    df1.drop(columns=['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019'], inplace=True)
    return df1

# %%
df_t_uw = uw_index(df_t_uw,0.5,7)

# %%
df_t_uw.tail()
# Out:
#       FACUL_NUM DIVISION_NUM  weighted_hazard  SUBMISSION_ID      SEGMENT_LOB  \
# 3254  FA0020373            1         0.238015           3255  Ppty Non Energy
# 3255  FA0045173            1         0.238015           3256  Ppty Non Energy
# 3256  FA0045173            1         0.238015           3257  Ppty Non Energy
# 3257  FA0041457            1         0.004342           3258  Ppty Non Energy
# 3258  02F052652            1         0.000656           3259  Ppty Non Energy
#
#       UWYEAR  CT_PERIOD            MAINOCCUPANCY SECTOR BUSINESSUNIT UWCENTER  \
# 3254    2017         12                 Textiles  BS CP  BS Property      LAC
# 3255    2018         12                 Textiles  BS CP  BS Property      LAC
# 3256    2019         12                 Textiles  BS CP  BS Property      LAC
# 3257    2020         12       Telecommunications  BS CP  BS Property     EMEA
# 3258    2017         12  Industrial Conglomerate  BS CP  BS Property     EMEA
#
#      SCOPE_PERILS         SUBSIDIARY        PARTTYPE GUARANTEE  \
# 3254    All Risks  XXX ASIA PACIFIC     Quota-Share        EU
# 3255    All Risks  XXX ASIA PACIFIC     Quota-Share        EU
# 3256    All Risks  XXX ASIA PACIFIC     Quota-Share        EU
# 3257    All Risks            XXX UK     Quota-Share        EU
# 3258    All Risks   XXX REASSURANCE  Excess of Loss        EU
#
#               MAIN_PRICING_CATEG         BI_TYPE  BI_PERIOD  INSUREDVALUEPD  \
# 3254            Textile industry  Loss of profit        0.0    8.879303e+08
# 3255            Textile industry  Loss of profit        0.0    8.269586e+08
# 3256            Textile industry  Loss of profit        0.0    8.918579e+08
# 3257  Telecommunications & Media   Gross earning       12.0    4.614703e+08
# 3258              Food producers  Loss of profit       24.0    8.977364e+09
#
#       INSUREDVALUEBI  TOTALINSUREDVALUE  NBLOCS  OIL        LIMIT  ATTACHMENT  \
# 3254    0.000000e+00       8.879303e+08       1  0.0  515340000.0         0.0
# 3255    0.000000e+00       8.269586e+08       1  0.0  467082000.0         0.0
# 3256    0.000000e+00       8.918579e+08       1  0.0  475650000.0         0.0
# 3257    7.331092e+07       5.347813e+08     395  0.0   90317917.0         0.0
# 3258    8.954379e+09       1.793174e+10     507  0.0  238534455.0  69600705.0
#
#       XXX_SHARE  MODELED_CAT_EXPLOSS  DISCOUNTS  DEDUCTION  EXT_EXPENSE  \
# 3254       0.075             0.000000        0.0   0.043635     0.043635
# 3255       0.075             0.000000        0.0   0.052358     0.052358
# 3256       0.025             0.000000        0.0   0.038689     0.038689
# 3257       0.100         42026.986571        0.0   0.000000     0.000000
# 3258       0.090             0.000000        0.0   1.201958     1.201958
#
#        WORDING QUALITY_RISK_MGT ASSET_QUALITY   BI_MITIGATION MB_QUALITY  \
# 3254  Standard          Average       Average  Non applicable    Average
# 3255  Standard          Average       Average  Non applicable    Average
# 3256  Standard          Average       Average  Non applicable    Average
# 3257  Standard          Average       Average         Average    Average
# 3258  Standard          Average       Average         Average    Average
#
#       TXCHANGE   FXRATEUSD       TOP_MPL  TOP_FMLS  PD_price(M)  \
# 3254  0.000041   4,402E-05  1.044505e+08       0.0          0.9
# 3255  0.000037   4,401E-05  9.466942e+07       0.0          0.0
# 3256  0.000038   4,291E-05  9.640601e+07       0.0          0.0
# 3257  0.903179           1  6.789087e+07       0.0          0.0
# 3258  0.067573  0,07272936  8.037121e+08       0.0          0.0
#
#       BI_time(Days)  Both_price(M)  PD_percent_loss (%)  COVER_BI  \
# 3254            0.0            0.0                  0.0     False
# 3255            0.0            0.0                 10.0     False
# 3256            0.0            0.0                 10.0     False
# 3257            0.0            0.0                  0.0      True
# 3258            0.0            0.0                  0.0      True
#
#      GEO_MARKET_SEGMENT UWYEAR_label  INCEPTION_month  uw_index
# 3254      Emerging Asia            1                5  0.000000
# 3255      Emerging Asia            1                5  0.000000
# 3256      Emerging Asia            1                5  0.000000
# 3257             Others            1                6  1.363152
# 3258             Africa            1                9  0.019349

# %% [markdown]
# ### Market Index
#
# Please find the detailed explanation of market index for each index in **Market Data Scrapping** notebook. In general, we create an index to indicate the market situation for each industry.

# %%
df_fd = pd.read_csv('data/market_values.csv')

# %%
data = []

for i, row in tqdm(df_t_uw.iterrows()):
    year = row['UWYEAR']#[:4]
    mpc = row["MAIN_PRICING_CATEG"]
    ratio = df_fd[df_fd["MAIN_PRICING_CATEG"] == mpc][str(year)]
    try :
        ratio = float(ratio)
    except:
        print(mpc)
        print(ratio)
    data.append(ratio)
    type(ratio)

data = df_t_uw.assign(financial_ratio = data)
data.head()
# Out:
# 3259it [00:03, 1081.65it/s]
#    FACUL_NUM DIVISION_NUM  weighted_hazard  SUBMISSION_ID      SEGMENT_LOB  \
# 0  FA0020462            1         0.449224              1  Ppty Non Energy
# 1  11F008861            1         0.479085              2  Ppty Non Energy
# 2  FA0003626            1         2.872240              3  Ppty Non Energy
# 3  11F007069            2         0.025928              4  Ppty Non Energy
# 4  11F008861            1         0.449208              5  Ppty Non Energy
#
#    UWYEAR  CT_PERIOD          MAINOCCUPANCY     SECTOR BUSINESSUNIT UWCENTER  \
# 0    2020         12  Precious Metals Mines  BS Energy    BS Energy      LAC
# 1    2019         12  Precious Metals Mines  BS Energy    BS Energy      LAC
# 2    2017         12  Precious Metals Mines  BS Energy    BS Energy      LAC
# 3    2018         12  Precious Metals Mines  BS Energy    BS Energy      LAC
# 4    2020         12  Precious Metals Mines  BS Energy    BS Energy      LAC
#
#   SCOPE_PERILS   SUBSIDIARY        PARTTYPE GUARANTEE  MAIN_PRICING_CATEG  \
# 0    All Risks  XXX CANADA     Quota-Share        EU  Mining - Hard Rock
# 1    All Risks  XXX CANADA     Quota-Share        EU  Mining - Hard Rock
# 2    All Risks   XXX RE US  Excess of Loss        EU  Mining - Hard Rock
# 3    All Risks  XXX CANADA     Quota-Share        EU  Mining - Hard Rock
# 4    All Risks  XXX CANADA     Quota-Share        EU  Mining - Hard Rock
#
#           BI_TYPE  BI_PERIOD  INSUREDVALUEPD  INSUREDVALUEBI  \
# 0  Loss of profit       12.0    6.386765e+08    3.094686e+08
# 1  Loss of profit       12.0    6.120514e+08    1.912141e+08
# 2  Loss of profit       24.0    1.585276e+09    5.624312e+08
# 3  Loss of profit       24.0    8.259934e+08    9.739950e+08
# 4  Loss of profit       12.0    6.387283e+08    3.094292e+08
#
#    TOTALINSUREDVALUE  NBLOCS  OIL        LIMIT  ATTACHMENT  XXX_SHARE  \
# 0       9.481450e+08       3  0.0  180635834.0         0.0       0.025
# 1       8.032655e+08       3  0.0  175963400.0         0.0       0.075
# 2       2.147707e+09       1  0.0  278732700.0         0.0       0.075
# 3       1.799988e+09       2  0.0  589622642.0         0.0       0.120
# 4       9.481575e+08       3  0.0  180635834.0         0.0       0.075
#
#    MODELED_CAT_EXPLOSS  DISCOUNTS  DEDUCTION  EXT_EXPENSE   WORDING  \
# 0                  0.0        0.0   0.072997     0.072997  Standard
# 1                  0.0        0.0   0.093420     0.093420  Standard
# 2                  0.0        0.0   0.095564     0.095564  Standard
# 3                  0.0        0.0   0.635696     0.635696  Standard
# 4                  0.0        0.0   0.080394     0.080394  Standard
#
#   QUALITY_RISK_MGT ASSET_QUALITY BI_MITIGATION MB_QUALITY  TXCHANGE FXRATEUSD  \
# 0          Average       Average       Average    Average  0.903179         1
# 1          Average       Average       Average    Average  0.879817         1
# 2          Average       Average       Average    Average  0.929109         1
# 3          Average       Average       Average    Average  0.842318         1
# 4          Average       Average       Average    Average  0.903179         1
#
#         TOP_MPL  TOP_FMLS  PD_price(M)  BI_time(Days)  Both_price(M)  \
# 0  2.500444e+08       0.0          0.5           30.0            0.0
# 1  2.097005e+08       0.0          0.4           30.0            0.0
# 2  8.826536e+08       0.0          4.6           30.0            0.0
# 3  9.285377e+08       0.0          2.1           30.0            0.0
# 4  2.500452e+08       0.0          0.5           30.0            0.0
#
#    PD_percent_loss (%)  COVER_BI GEO_MARKET_SEGMENT UWYEAR_label  \
# 0                  0.0      True      Latin America            1
# 1                  0.0      True      Latin America            1
# 2                  0.0      True      Latin America            1
# 3                  0.0      True      Latin America            1
# 4                  0.0      True      Latin America            1
#
#    INCEPTION_month  uw_index  financial_ratio
# 0                6  0.051708         1.177278
# 1                6  0.144084         1.076494
# 2               10  0.000000         1.159407
# 3                5  0.000000         1.042942
# 4                6  0.076720         1.177278

# %% [markdown]
# # <font color='darkorange'> Save processed data </font>

# %%
#Original data with the preprocessing of column 'Deductible'
if preprocess_train:
    data.to_csv('data/processed_data_train.csv', index=False)
else:
    data.to_csv('data/processed_data_test.csv', index=False)

# %% [markdown]
# Our final dataset now looks like this. We are now ready to train our models.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3259 entries, 0 to 3258
# Data columns (total 49 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FACUL_NUM            3259 non-null   object
#  1   DIVISION_NUM         3259 non-null   object
#  2   weighted_hazard      3259 non-null   float64
#  3   SUBMISSION_ID        3259 non-null   int64
#  4   SEGMENT_LOB          3259 non-null   object
#  5   UWYEAR               3259 non-null   int64
#  6   CT_PERIOD            3259 non-null   int64
#  7   MAINOCCUPANCY        3259 non-null   object
#  8   SECTOR               3259 non-null   object
#  9   BUSINESSUNIT         3259 non-null   object
#  10  UWCENTER             3259 non-null   object
#  11  SCOPE_PERILS         3259 non-null   object
#  12  SUBSIDIARY           3259 non-null   object
#  13  PARTTYPE             3259 non-null   object
#  14  GUARANTEE            3259 non-null   object
#  15  MAIN_PRICING_CATEG   3259 non-null   object
#  16  BI_TYPE              3259 non-null   object
#  17  BI_PERIOD            3259 non-null   float64
#  18  INSUREDVALUEPD       3259 non-null   float64
#  19  INSUREDVALUEBI       3259 non-null   float64
#  20  TOTALINSUREDVALUE    3259 non-null   float64
#  21  NBLOCS               3259 non-null   int64
#  22  OIL                  3259 non-null   float64
#  23  LIMIT                3259 non-null   float64
#  24  ATTACHMENT           3259 non-null   float64
#  25  XXX_SHARE           3259 non-null   float64
#  26  MODELED_CAT_EXPLOSS  3259 non-null   float64
#  27  DISCOUNTS            3259 non-null   float64
#  28  DEDUCTION            3259 non-null   float64
#  29  EXT_EXPENSE          3259 non-null   float64
#  30  WORDING              3259 non-null   object
#  31  QUALITY_RISK_MGT     3259 non-null   object
#  32  ASSET_QUALITY        3259 non-null   object
#  33  BI_MITIGATION        3259 non-null   object
#  34  MB_QUALITY           3259 non-null   object
#  35  TXCHANGE             3259 non-null   float64
#  36  FXRATEUSD            3259 non-null   object
#  37  TOP_MPL              3259 non-null   float64
#  38  TOP_FMLS             3259 non-null   float64
#  39  PD_price(M)          3259 non-null   float64
#  40  BI_time(Days)        3259 non-null   float64
#  41  Both_price(M)        3259 non-null   float64
#  42  PD_percent_loss (%)  3259 non-null   float64
#  43  COVER_BI             3259 non-null   bool
#  44  GEO_MARKET_SEGMENT   3259 non-null   object
#  45  UWYEAR_label         3259 non-null   object
#  46  INCEPTION_month      3259 non-null   int64
#  47  uw_index             3259 non-null   float64
#  48  financial_ratio      3259 non-null   float64
# dtypes: bool(1), float64(22), int64(5), object(21)
# memory usage: 1.2+ MB
