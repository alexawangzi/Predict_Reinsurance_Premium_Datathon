# %% [markdown]
# <center> <h1>XXX Datathon - Team n°1</h1> </center>

# %% [markdown]
# ## In this notebook:
#
# In this notebook, we will build a **AutoML** instance using the **H2O AutoML library**
# (https://docs.h2o.ai/h2o/latest-stable/h2o-docs/automl.html#).
#
# AutoML, or Automated machine learning, automatically generating a data analysis pipeline that can include data pre-processing, feature selection, and feature engineering methods along with machine learning methods and parameter settings that are optimized for your data. Traditionally, the above-mentioned steps are very time consuming and requires expertise. The aim of AutoML, therefore, is to perform these steps qucikly and make data science and machine learning more readily accessible. (http://automl.info)
#
# We want to experiment this tool and see whether it could help us.

# %%
#Database Management
import numpy as np 
import pandas as pd 

#Sklearn
from sklearn.model_selection import train_test_split

#Other
#!pip install h2o
import h2o
from h2o.automl import H2OAutoML
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 5000)
pd.set_option('display.max_rows', 5000)

# %% [markdown]
# # <font color='darkorange'>Loading the dataset, train/test split </font>

# %%
df = pd.read_csv('./data/processed_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5191 entries, 0 to 5190
# Data columns (total 54 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FACUL_NUM              5191 non-null   object
#  1   DIVISION_NUM           5191 non-null   int64
#  2   SEGMENT_LOB            5191 non-null   object
#  3   UWYEAR                 5191 non-null   int64
#  4   CT_PERIOD              5191 non-null   float64
#  5   MAINOCCUPANCY          5191 non-null   object
#  6   SECTOR                 5191 non-null   object
#  7   BUSINESSUNIT           5191 non-null   object
#  8   UWCENTER               5191 non-null   object
#  9   SCOPE_PERILS           5191 non-null   object
#  10  SUBSIDIARY             5191 non-null   object
#  11  PARTTYPE               5191 non-null   object
#  12  GUARANTEE              5191 non-null   object
#  13  MAIN_PRICING_CATEG     5191 non-null   object
#  14  BI_TYPE                5191 non-null   object
#  15  BI_PERIOD              5191 non-null   float64
#  16  TC_PROFIT_COMMISSION   5191 non-null   float64
#  17  INSUREDVALUEPD         5191 non-null   float64
#  18  INSUREDVALUEBI         5191 non-null   float64
#  19  TOTALINSUREDVALUE      5191 non-null   float64
#  20  NBLOCS                 5191 non-null   float64
#  21  OIL                    5191 non-null   float64
#  22  LIMIT                  5191 non-null   float64
#  23  ATTACHMENT             5191 non-null   float64
#  24  XXX_SHARE             5191 non-null   float64
#  25  PREMIUM                5191 non-null   float64
#  26  MODELED_CAT_EXPLOSS    5191 non-null   float64
#  27  DISCOUNTS              5191 non-null   float64
#  28  DEDUCTION              5191 non-null   float64
#  29  EXT_EXPENSE            5191 non-null   float64
#  30  WORDING                5191 non-null   object
#  31  QUALITY_RISK_MGT       5191 non-null   object
#  32  ASSET_QUALITY          5191 non-null   object
#  33  BI_MITIGATION          5191 non-null   object
#  34  MB_QUALITY             5191 non-null   object
#  35  TXCHANGE               5191 non-null   float64
#  36  FXRATEUSD              5191 non-null   float64
#  37  TOP_MPL                5191 non-null   float64
#  38  TOP_FMLS               5191 non-null   float64
#  39  PD_price(M)            5191 non-null   float64
#  40  BI_price(M)            5191 non-null   float64
#  41  BI_time(Days)          5191 non-null   float64
#  42  Both_price(M)          5191 non-null   float64
#  43  PD_percent_loss (%)    5191 non-null   float64
#  44  BI_percent_loss (%)    5191 non-null   float64
#  45  Both_percent_loss (%)  5191 non-null   float64
#  46  PD_percent_tiv (%)     5191 non-null   float64
#  47  COVER_BI               5191 non-null   bool
#  48  GEO_MARKET_SEGMENT     5191 non-null   object
#  49  UWYEAR_label           5191 non-null   int64
#  50  INCEPTION_month        5191 non-null   int64
#  51  WEIGHTED_HAZARD        5191 non-null   float64
#  52  uw_index               5191 non-null   float64
#  53  financial_ratio        5191 non-null   float64
# dtypes: bool(1), float64(31), int64(4), object(18)
# memory usage: 2.1+ MB

# %%
train, test = train_test_split(df, test_size=0.2)

# %% [markdown]
# # <font color='darkorange'> AutoML </font>
#
# We use the H2O AutoML library. The current version trains and cross-validates the following algorithms (in the following order):
#
# - three pre-specified XGBoost GBM (Gradient Boosting Machine) models
# - a fixed grid of GLMs
# - a default Random Forest (DRF)
# - five pre-specified H2O GBMs
# - a near-default Deep Neural Net
# - an Extremely Randomized Forest (XRT)
# - a random grid of XGBoost GBMs
# - a random grid of H2O GBMs
# - a random grid of Deep Neural Nets.
#
# In some cases, there will not be enough time to complete all the algorithms, so some may be missing from the leaderboard. AutoML then trains additionaly two Stacked Ensemble models.
#
# As a first step, we need to initialize an H2O instance.

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         30 mins 58 secs
# H2O_cluster_timezone:       Europe/Paris
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.0.4
# H2O_cluster_version_age:    1 month and 5 days
# H2O_cluster_name:           H2O_from_python_ziwang_b32vfn
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.772 Gb
# H2O_cluster_total_cores:    12
# H2O_cluster_allowed_cores:  12
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.7.6 final
# --------------------------  ------------------------------------------------------------------

# %% [markdown]
# We now create a H2OFrame, which holds our training data. This frame is going to be fed to the AutoML model to perform computation. We also define the predictors and response variables.

# %%
hf = h2o.H2OFrame(train)

predictors = hf.drop('PREMIUM').columns
response = 'PREMIUM'
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %% [markdown]
# Now we create a AutoML instance and train it on the frame we created to generate a leaderboard of models.

# %%
aml = H2OAutoML(
    max_models=20,
    max_runtime_secs=300,
    seed=1234
)

aml.train(x=predictors,
        y=response,
        training_frame=hf,
)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
lb = aml.leaderboard
lb.head(rows=10)
# Out:
# <table>
# <thead>
# <tr><th>model_id                                           </th><th style="text-align: right;">  mean_residual_deviance</th><th style="text-align: right;">  rmse</th><th style="text-align: right;">        mse</th><th style="text-align: right;">    mae</th><th style="text-align: right;">  rmsle</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_BestOfFamily_AutoML_20210306_201945</td><td style="text-align: right;">             1.97074e+10</td><td style="text-align: right;">140383</td><td style="text-align: right;">1.97074e+10</td><td style="text-align: right;">59936.2</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>StackedEnsemble_AllModels_AutoML_20210306_201945   </td><td style="text-align: right;">             2.01257e+10</td><td style="text-align: right;">141865</td><td style="text-align: right;">2.01257e+10</td><td style="text-align: right;">59500.1</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>GBM_1_AutoML_20210306_201945                       </td><td style="text-align: right;">             2.28406e+10</td><td style="text-align: right;">151131</td><td style="text-align: right;">2.28406e+10</td><td style="text-align: right;">59352.7</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>XGBoost_3_AutoML_20210306_201945                   </td><td style="text-align: right;">             2.3237e+10 </td><td style="text-align: right;">152437</td><td style="text-align: right;">2.3237e+10 </td><td style="text-align: right;">66023  </td><td style="text-align: right;">    nan</td></tr>
# <tr><td>GBM_grid__1_AutoML_20210306_201945_model_2         </td><td style="text-align: right;">             2.36774e+10</td><td style="text-align: right;">153874</td><td style="text-align: right;">2.36774e+10</td><td style="text-align: right;">58012.1</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>GBM_3_AutoML_20210306_201945                       </td><td style="text-align: right;">             2.48215e+10</td><td style="text-align: right;">157549</td><td style="text-align: right;">2.48215e+10</td><td style="text-align: right;">60611.7</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20210306_201945_model_1     </td><td style="text-align: right;">             2.50851e+10</td><td style="text-align: right;">158383</td><td style="text-align: right;">2.50851e+10</td><td style="text-align: right;">66207.6</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>GBM_2_AutoML_20210306_201945                       </td><td style="text-align: right;">             2.55505e+10</td><td style="text-align: right;">159845</td><td style="text-align: right;">2.55505e+10</td><td style="text-align: right;">62366.1</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>GBM_4_AutoML_20210306_201945                       </td><td style="text-align: right;">             2.57599e+10</td><td style="text-align: right;">160499</td><td style="text-align: right;">2.57599e+10</td><td style="text-align: right;">60171.4</td><td style="text-align: right;">    nan</td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20210306_201945_model_3     </td><td style="text-align: right;">             2.7009e+10 </td><td style="text-align: right;">164344</td><td style="text-align: right;">2.7009e+10 </td><td style="text-align: right;">67124.5</td><td style="text-align: right;">    nan</td></tr>
# </tbody>
# </table>

# %% [markdown]
# Upon first look, tree-like structures scuch as GBM and XGBoost seem to perform well.

# %% [markdown]
# # <font color='darkorange'>Deep dive into the AutoML results </font>
#
#
# To avoid overfittig, let's examine the train, validation and test performance of the No.1 ranking model.

# %%
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])
m0 = h2o.get_model(model_ids[0])  
m0.explain
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_BestOfFamily_AutoML_20210306_201945
#
# No model summary for this model
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 2362052959.0505233
# RMSE: 48600.95635942284
# MAE: 29340.13515534512
# RMSLE: NaN
# R^2: 0.9748720142032873
# Mean Residual Deviance: 2362052959.0505233
# Null degrees of freedom: 4151
# Residual degrees of freedom: 4148
# Null deviance: 390291683755277.8
# Residual deviance: 9807243885977.773
# AIC: 101404.63862302399
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 19707377881.950706
# RMSE: 140382.96863206272
# MAE: 59936.1950519356
# RMSLE: NaN
# R^2: 0.7903490226115972
# Mean Residual Deviance: 19707377881.950706
# Null degrees of freedom: 4151
# Residual degrees of freedom: 4148
# Null deviance: 390442747169562.75
# Residual deviance: 81825032965859.33
# AIC: 110212.94859212307
# <bound method explain of >

# %%
hf_test = h2o.H2OFrame(test)

aml.leader.model_performance(hf_test)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on test data. **
#
# MSE: 21714116251.622528
# RMSE: 147357.10451696086
# MAE: 61759.31460377956
# RMSLE: NaN
# R^2: 0.7456351311449001
# Mean Residual Deviance: 21714116251.622528
# Null degrees of freedom: 1038
# Residual degrees of freedom: 1035
# Null deviance: 88696406085753.73
# Residual deviance: 22560966785435.81
# AIC: 27688.030584280343

# %% [markdown]
# There seems to be an issue of overfitting, since the test RMSE bigger than the train RMSE.
# Now we take a look at the best performing single model: GBM

# %%
m2 = h2o.get_model(model_ids[2]) 
m2.explain
# Out:
# Model Details
# =============
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  GBM_1_AutoML_20210306_201945
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0               97.0                      97.0              84388.0
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0        6.0        6.0         6.0        32.0        63.0     51.42268
# ModelMetricsRegression: gbm
# ** Reported on train data. **
#
# MSE: 851254709.3190936
# RMSE: 29176.26962651486
# MAE: 20194.57110341232
# RMSLE: NaN
# Mean Residual Deviance: 851254709.3190936
#
# ModelMetricsRegression: gbm
# ** Reported on cross-validation data. **
#
# MSE: 22840627400.555138
# RMSE: 151131.15959508528
# MAE: 59352.65349862437
# RMSLE: NaN
# Mean Residual Deviance: 22840627400.555138
#
# Cross-Validation Metrics Summary:
#                                     mean           sd    cv_1_valid  \
# 0                     mae      59351.484    5811.2476      68823.15
# 1  mean_residual_deviance  2.28386714E10  8.7825019E9  3.6636443E10
# 2                     mse  2.28386714E10  8.7825019E9  3.6636443E10
# 3                      r2     0.76057994  0.050299212    0.69457316
# 4       residual_deviance  2.28386714E10  8.7825019E9  3.6636443E10
# 5                    rmse       148995.9     28259.79     191406.48
# 6                   rmsle            NaN          0.0           NaN
#
#       cv_2_valid     cv_3_valid     cv_4_valid     cv_5_valid
# 0      54737.953       60198.73      54615.742      58381.844
# 1  1.71650007E10  2.41898537E10  1.36713482E10  2.25307095E10
# 2  1.71650007E10  2.41898537E10  1.36713482E10  2.25307095E10
# 3      0.7430632      0.7466154      0.8252824      0.7933656
# 4  1.71650007E10  2.41898537E10  1.36713482E10  2.25307095E10
# 5      131015.27      155530.88      116924.54      150102.33
# 6            NaN            NaN            NaN            NaN
# Scoring History:
#                 timestamp    duration  number_of_trees  training_rmse  \
# 0     2021-03-06 20:20:08   2.185 sec              0.0  306595.641235
# 1     2021-03-06 20:20:08   2.220 sec              5.0  214335.453882
# 2     2021-03-06 20:20:08   2.253 sec             10.0  158685.944094
# 3     2021-03-06 20:20:08   2.291 sec             15.0  121776.936717
# 4     2021-03-06 20:20:08   2.326 sec             20.0   96907.852814
# 5     2021-03-06 20:20:09   2.359 sec             25.0   81720.048292
# 6     2021-03-06 20:20:09   2.405 sec             30.0   70739.845425
# 7     2021-03-06 20:20:09   2.450 sec             35.0   62923.767205
# 8     2021-03-06 20:20:09   2.489 sec             40.0   56144.499859
# 9     2021-03-06 20:20:09   2.524 sec             45.0   51577.018522
# 10    2021-03-06 20:20:09   2.556 sec             50.0   47197.881358
# 11    2021-03-06 20:20:09   2.585 sec             55.0   44309.874006
# 12    2021-03-06 20:20:09   2.615 sec             60.0   41543.601304
# 13    2021-03-06 20:20:09   2.642 sec             65.0   39509.528424
# 14    2021-03-06 20:20:09   2.670 sec             70.0   37496.068409
# 15    2021-03-06 20:20:09   2.702 sec             75.0   36016.130614
# 16    2021-03-06 20:20:09   2.732 sec             80.0   34363.859256
# 17    2021-03-06 20:20:09   2.764 sec             85.0   32410.585948
# 18    2021-03-06 20:20:09   2.793 sec             90.0   30859.466119
# 19    2021-03-06 20:20:09   2.823 sec             95.0   29601.240592
#
#      training_mae  training_deviance
# 0   156899.467009       9.400089e+10
# 1   110063.879654       4.593969e+10
# 2    82895.701592       2.518123e+10
# 3    66730.463661       1.482962e+10
# 4    56062.434868       9.391132e+09
# 5    49059.531719       6.678166e+09
# 6    43638.719076       5.004126e+09
# 7    39671.531190       3.959400e+09
# 8    36085.031643       3.152205e+09
# 9    33521.286783       2.660189e+09
# 10   31020.289816       2.227640e+09
# 11   29336.951027       1.963365e+09
# 12   27700.530096       1.725871e+09
# 13   26509.007750       1.561003e+09
# 14   25236.383783       1.405955e+09
# 15   24276.821606       1.297162e+09
# 16   23387.642088       1.180875e+09
# 17   22185.970004       1.050446e+09
# 18   21310.629070       9.523066e+08
# 19   20482.798724       8.762334e+08
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#                variable  relative_importance  scaled_importance  percentage
# 0     TOTALINSUREDVALUE         4.464974e+14           1.000000    0.238918
# 1        INSUREDVALUEPD         2.124187e+14           0.475745    0.113664
# 2            XXX_SHARE         2.090584e+14           0.468219    0.111866
# 3         MAINOCCUPANCY         2.008569e+14           0.449850    0.107477
# 4    MAIN_PRICING_CATEG         1.229396e+14           0.275342    0.065784
# 5   MODELED_CAT_EXPLOSS         1.198851e+14           0.268501    0.064150
# 6        INSUREDVALUEBI         4.897112e+13           0.109678    0.026204
# 7              uw_index         4.506616e+13           0.100933    0.024115
# 8         BI_time(Days)         3.733633e+13           0.083620    0.019978
# 9                UWYEAR         3.646254e+13           0.081664    0.019511
# 10   GEO_MARKET_SEGMENT         3.496634e+13           0.078313    0.018710
# 11               SECTOR         3.085868e+13           0.069113    0.016512
# 12           ATTACHMENT         2.752465e+13           0.061646    0.014728
# 13            FACUL_NUM         2.696326e+13           0.060388    0.014428
# 14          PD_price(M)         2.144603e+13           0.048032    0.011476
# 15      WEIGHTED_HAZARD         2.103688e+13           0.047115    0.011257
# 16                LIMIT         2.052192e+13           0.045962    0.010981
# 17          EXT_EXPENSE         1.867130e+13           0.041817    0.009991
# 18      INCEPTION_month         1.804088e+13           0.040405    0.009654
# 19      financial_ratio         1.573142e+13           0.035233    0.008418
# See the whole table with table.as_data_frame()
# <bound method explain of >

# %%
m2.model_performance(hf_test)
# Out:
# ModelMetricsRegression: gbm
# ** Reported on test data. **
#
# MSE: 22157806169.9135
# RMSE: 148854.98369189224
# MAE: 60580.09890986102
# RMSLE: NaN
# Mean Residual Deviance: 22157806169.9135

# %% [markdown]
# The train and test RMSE are similar.

# %% [markdown]
# # <font color='darkorange'>Conclusion </font>
#
#
# This experiement shows that AutoML result cannot replace hand-selected models for several reasons:
#
# - Overfitting is not considered when ranking the models
# - The data could be better prepared for certain models or only selecting features of importance but this aspect is not explored.
# - The best models are the ensemble models, but it is posisble that the best ensemble models should be structured using some different base models.
# - ...
#
# However, AutoML results can be useful for several reasons:
#
# - Serves as good baseline
# - Provide hints on parameter tuning
# - ...
#
# Although AutoML result should not be directly used, it is interesting to integrate it into our workflow and to get a sense that in general, tree-like models perform well on our dataset.
